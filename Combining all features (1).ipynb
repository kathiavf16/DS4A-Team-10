# %% [markdown]
# # Combining all features, preparing data for analysis
#
# 1) Get flags of interest and entropy indexes for USDA final
# 2) merge features 2010 and 2015

# %%
import pandas as pd 

# read 2010 features
features_2010 = pd.read_csv('2010_features_by_state.csv')

# read 2015 features
features_2015 = pd.read_csv('2015_features_by_state.csv')

# read usda dataselt
usda = pd.read_csv('final_usda.csv')

# %% [markdown]
# # 1) Limit the USDA df to vars of interest

# %%
list(usda.columns)
# Out:
# ['CensusTract',
#  'HUNVFlag_x',
#  'LILATracts_1And10_x',
#  'LILATracts_halfAnd10_x',
#  'LILATracts_Vehicle_x',
#  'LILATracts_1And20_x',
#  'LATracts1_x',
#  'LATracts10_x',
#  'LATracts20_x',
#  'LATracts_half_x',
#  'entropy_index15_x',
#  'HUNVFlag_y',
#  'LILATracts_1And10_y',
#  'LILATracts_halfAnd10_y',
#  'LILATracts_Vehicle_y',
#  'LILATracts_1And20_y',
#  'LATracts1_y',
#  'LATracts10_y',
#  'LATracts20_y',
#  'LATracts_half_y',
#  'entropy_index10_x',
#  'HUNVFlag_diff',
#  'LILATracts_1And10_diff',
#  'LILATracts_halfAnd10_diff',
#  'LILATracts_Vehicle_diff',
#  'LILATracts_1And20_diff',
#  'LATracts1_diff',
#  'LATracts10_diff',
#  'LATracts20_diff',
#  'LATracts_half_diff',
#  'State_x',
#  'County_x',
#  'Urban_x',
#  'POP2010_x',
#  'OHU2010_x',
#  'GroupQuartersFlag_x',
#  'NUMGQTRS_x',
#  'PCTGQTRS_x',
#  'LILATracts_1And10_x.1',
#  'LILATracts_halfAnd10_x.1',
#  'LILATracts_1And20_x.1',
#  'LILATracts_Vehicle_x.1',
#  'HUNVFlag_x.1',
#  'LowIncomeTracts_x',
#  'PovertyRate',
#  'MedianFamilyIncome',
#  'LA1and10_x',
#  'LAhalfand10_x',
#  'LA1and20_x',
#  'LATracts_half_x.1',
#  'LATracts1_x.1',
#  'LATracts10_x.1',
#  'LATracts20_x.1',
#  'LATractsVehicle_20_x',
#  'LAPOP1_10',
#  'LAPOP05_10',
#  'LAPOP1_20',
#  'LALOWI1_10',
#  'LALOWI05_10',
#  'LALOWI1_20',
#  'lapophalf_x',
#  'lapophalfshare_x',
#  'lalowihalf_x',
#  'lalowihalfshare_x',
#  'lakidshalf_x',
#  'lakidshalfshare_x',
#  'laseniorshalf_x',
#  'laseniorshalfshare_x',
#  'lawhitehalf',
#  'lawhitehalfshare',
#  'lablackhalf',
#  'lablackhalfshare',
#  'laasianhalf',
#  'laasianhalfshare',
#  'lanhopihalf',
#  'lanhopihalfshare',
#  'laaianhalf',
#  'laaianhalfshare',
#  'laomultirhalf',
#  'laomultirhalfshare',
#  'lahisphalf',
#  'lahisphalfshare',
#  'lahunvhalf_x',
#  'lahunvhalfshare_x',
#  'lasnaphalf',
#  'lasnaphalfshare',
#  'lapop1_x',
#  'lapop1share_x',
#  'lalowi1_x',
#  'lalowi1share_x',
#  'lakids1_x',
#  'lakids1share_x',
#  'laseniors1_x',
#  'laseniors1share_x',
#  'lawhite1',
#  'lawhite1share',
#  'lablack1',
#  'lablack1share',
#  'laasian1',
#  'laasian1share',
#  'lanhopi1',
#  'lanhopi1share',
#  'laaian1',
#  'laaian1share',
#  'laomultir1',
#  'laomultir1share',
#  'lahisp1',
#  'lahisp1share',
#  'lahunv1_x',
#  'lahunv1share_x',
#  'lasnap1',
#  'lasnap1share',
#  'lapop10_x',
#  'lapop10share_x',
#  'lalowi10_x',
#  'lalowi10share_x',
#  'lakids10_x',
#  'lakids10share_x',
#  'laseniors10_x',
#  'laseniors10share_x',
#  'lawhite10',
#  'lawhite10share',
#  'lablack10',
#  'lablack10share',
#  'laasian10',
#  'laasian10share',
#  'lanhopi10',
#  'lanhopi10share',
#  'laaian10',
#  'laaian10share',
#  'laomultir10',
#  'laomultir10share',
#  'lahisp10',
#  'lahisp10share',
#  'lahunv10_x',
#  'lahunv10share_x',
#  'lasnap10',
#  'lasnap10share',
#  'lapop20_x',
#  'lapop20share_x',
#  'lalowi20_x',
#  'lalowi20share_x',
#  'lakids20_x',
#  'lakids20share_x',
#  'laseniors20_x',
#  'laseniors20share_x',
#  'lawhite20',
#  'lawhite20share',
#  'lablack20',
#  'lablack20share',
#  'laasian20',
#  'laasian20share',
#  'lanhopi20',
#  'lanhopi20share',
#  'laaian20',
#  'laaian20share',
#  'laomultir20',
#  'laomultir20share',
#  'lahisp20',
#  'lahisp20share',
#  'lahunv20_x',
#  'lahunv20share_x',
#  'lasnap20',
#  'lasnap20share',
#  'TractLOWI',
#  'TractKids',
#  'TractSeniors',
#  'TractWhite_x',
#  'TractBlack_x',
#  'TractAsian_x',
#  'TractNHOPI_x',
#  'TractAIAN_x',
#  'TractOMultir_x',
#  'TractHispanic_x',
#  'TractHUNV',
#  'TractSNAP',
#  'TractWhite_y',
#  'TractBlack_y',
#  'TractAsian_y',
#  'TractNHOPI_y',
#  'TractAIAN_y',
#  'TractOMultir_y',
#  'TractHispanic_y',
#  'totalpop',
#  'prop_white',
#  'prop_black',
#  'prop_asian',
#  'prop_hisp',
#  'prop_nhopi',
#  'prop_aian',
#  'prop_multir',
#  'totalprop',
#  'entropy_index15_y',
#  'State_y',
#  'County_y',
#  'LILATracts_1And10_y.1',
#  'LILATracts_halfAnd10_y.1',
#  'LILATracts_1And20_y.1',
#  'LILATracts_Vehicle_y.1',
#  'Urban_y',
#  'Rural',
#  'LA1and10_y',
#  'LAhalfand10_y',
#  'LA1and20_y',
#  'LATracts_half_y.1',
#  'LATracts1_y.1',
#  'LATracts10_y.1',
#  'LATracts20_y.1',
#  'LATractsVehicle_20_y',
#  'HUNVFlag_y.1',
#  'GroupQuartersFlag_y',
#  'OHU2010_y',
#  'NUMGQTRS_y',
#  'PCTGQTRS_y',
#  'LowIncomeTracts_y',
#  'POP2010_y',
#  'UATYP10',
#  'lapophalf_y',
#  'lapophalfshare_y',
#  'lalowihalf_y',
#  'lalowihalfshare_y',
#  'lakidshalf_y',
#  'lakidshalfshare_y',
#  'laseniorshalf_y',
#  'laseniorshalfshare_y',
#  'lahunvhalf_y',
#  'lahunvhalfshare_y',
#  'lapop1_y',
#  'lapop1share_y',
#  'lalowi1_y',
#  'lalowi1share_y',
#  'lakids1_y',
#  'lakids1share_y',
#  'laseniors1_y',
#  'laseniors1share_y',
#  'lahunv1_y',
#  'lahunv1share_y',
#  'lapop10_y',
#  'lapop10share_y',
#  'lalowi10_y',
#  'lalowi10share_y',
#  'lakids10_y',
#  'lakids10share_y',
#  'laseniors10_y',
#  'laseniors10share_y',
#  'lahunv10_y',
#  'lahunv10share_y',
#  'lapop20_y',
#  'lapop20share_y',
#  'lalowi20_y',
#  'lalowi20share_y',
#  'lakids20_y',
#  'lakids20share_y',
#  'laseniors20_y',
#  'laseniors20share_y',
#  'lahunv20_y',
#  'lahunv20share_y',
#  'census_tract',
#  'Unnamed: 0',
#  'geo_id',
#  'state',
#  'NAME',
#  'est_total',
#  'race_total',
#  'race_hisp_x',
#  'race_white_x',
#  'race_black_x',
#  'race_aian_x',
#  'race_asian_x',
#  'race_nhopi_x',
#  'race_other_x',
#  'race_multi1_x',
#  'race_multi2_x',
#  'race_multi3_x',
#  'state.1',
#  'county',
#  'tract',
#  'race_hisp_y',
#  'race_white_y',
#  'race_black_y',
#  'race_aian_y',
#  'race_asian_y',
#  'race_nhopi_y',
#  'race_other_y',
#  'race_multi1_y',
#  'race_multi2_y',
#  'race_multi3_y',
#  'totalpop10',
#  'prop_white10',
#  'prop_black10',
#  'prop_asian10',
#  'prop_hisp10',
#  'prop_nhopi10',
#  'prop_aian10',
#  'prop_multir10',
#  'entropy_index10_y']

# %%
# filter cols of interest
usda_df = usda[['geo_id', 'CensusTract', 'State_x', 'HUNVFlag_x', 'LILATracts_1And10_x', 'LILATracts_halfAnd10_x','LILATracts_Vehicle_x', 
                'LATracts1_y', 'LATracts10_y', 'LATracts20_y', 'LATracts_half_y',
                'LATracts1_x', 'LATracts10_x', 'LATracts20_x', 'LATracts_half_x',
                'LILATracts_1And20_x', 'HUNVFlag_y', 'LILATracts_1And10_y', 'LILATracts_halfAnd10_y','LILATracts_Vehicle_y', 
                'LILATracts_1And20_y', 'entropy_index10_y', 'entropy_index15_x', 'HUNVFlag_diff','LILATracts_1And10_diff','LILATracts_halfAnd10_diff','LILATracts_Vehicle_diff',
                'LILATracts_1And20_diff', 'LATracts1_diff', 'LATracts10_diff', 'LATracts20_diff','LATracts_half_diff']]

# set index to geo_Id
usda_df = usda_df.set_index('geo_id')

# drop duplicates
usda_df = usda_df.drop_duplicates()

# get df info
usda_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 62674 entries, 1400000US02013000100 to 1400000US50027966700
# Data columns (total 31 columns):
# CensusTract                  62674 non-null int64
# State_x                      62674 non-null object
# HUNVFlag_x                   62674 non-null int64
# LILATracts_1And10_x          62674 non-null int64
# LILATracts_halfAnd10_x       62674 non-null int64
# LILATracts_Vehicle_x         62674 non-null int64
# LATracts1_y                  62674 non-null int64
# LATracts10_y                 62674 non-null int64
# LATracts20_y                 62674 non-null int64
# LATracts_half_y              62674 non-null int64
# LATracts1_x                  62674 non-null int64
# LATracts10_x                 62674 non-null int64
# LATracts20_x                 62674 non-null int64
# LATracts_half_x              62674 non-null int64
# LILATracts_1And20_x          62674 non-null int64
# HUNVFlag_y                   62674 non-null int64
# LILATracts_1And10_y          62674 non-null int64
# LILATracts_halfAnd10_y       62674 non-null int64
# LILATracts_Vehicle_y         62674 non-null int64
# LILATracts_1And20_y          62674 non-null int64
# entropy_index10_y            62674 non-null float64
# entropy_index15_x            62674 non-null float64
# HUNVFlag_diff                62674 non-null int64
# LILATracts_1And10_diff       62674 non-null int64
# LILATracts_halfAnd10_diff    62674 non-null int64
# LILATracts_Vehicle_diff      62674 non-null int64
# LILATracts_1And20_diff       62674 non-null int64
# LATracts1_diff               62674 non-null int64
# LATracts10_diff              62674 non-null int64
# LATracts20_diff              62674 non-null int64
# LATracts_half_diff           62674 non-null int64
# dtypes: float64(2), int64(28), object(1)
# memory usage: 15.3+ MB

# %%
# set index to geo id
ft2010_df = features_2010.set_index('GEO_ID2010')
ft2010_df.head()
# Out:
#                       Unnamed: 0  STATE2010  \
# GEO_ID2010
# 1400000US01001020100           1          1
# 1400000US01001020200           2          1
# 1400000US01001020300           3          1
# 1400000US01001020400           4          1
# 1400000US01001020500           5          1
#
#                                                        NAME2010  \
# GEO_ID2010
# 1400000US01001020100  Census Tract 201, Autauga County, Alabama
# 1400000US01001020200  Census Tract 202, Autauga County, Alabama
# 1400000US01001020300  Census Tract 203, Autauga County, Alabama
# 1400000US01001020400  Census Tract 204, Autauga County, Alabama
# 1400000US01001020500  Census Tract 205, Autauga County, Alabama
#
#                       B01001_001E2010  B01001_002E2010  B01001_026E2010  \
# GEO_ID2010
# 1400000US01001020100             1809              898              911
# 1400000US01001020200             2020              882             1138
# 1400000US01001020300             3543             1508             2035
# 1400000US01001020400             4840             2218             2622
# 1400000US01001020500             9938             4962             4976
#
#                       B01002_001E2010  B01003_001E2010  B19037_001E2010  \
# GEO_ID2010
# 1400000US01001020100             41.9             1809              696
# 1400000US01001020200             39.0             2020              730
# 1400000US01001020300             33.7             3543             1287
# 1400000US01001020400             41.2             4840             1839
# 1400000US01001020500             33.5             9938             3741
#
#                       B19001_001E2010  ...  B19301_001E2010  B19131_002E2010  \
# GEO_ID2010                             ...
# 1400000US01001020100              696  ...          35830.0              472
# 1400000US01001020200              730  ...          18520.0              247
# 1400000US01001020300             1287  ...          20319.0              661
# 1400000US01001020400             1839  ...          25375.0             1071
# 1400000US01001020500             3741  ...          28102.0             1939
#
#                       B19131_003E2010  B19126_001E2010  B03002_009E2010  \
# GEO_ID2010
# 1400000US01001020100              210            76806               77
# 1400000US01001020200              133            49191                0
# 1400000US01001020300              352            53342                0
# 1400000US01001020400              404            67292               35
# 1400000US01001020500             1126            80176              112
#
#                       B03002_010E2010  B03002_011E2010  state2010  county2010  \
# GEO_ID2010
# 1400000US01001020100                0               77          1           1
# 1400000US01001020200                0                0          1           1
# 1400000US01001020300                0                0          1           1
# 1400000US01001020400                4               31          1           1
# 1400000US01001020500                0              112          1           1
#
#                       tract2010
# GEO_ID2010
# 1400000US01001020100      20100
# 1400000US01001020200      20200
# 1400000US01001020300      20300
# 1400000US01001020400      20400
# 1400000US01001020500      20500
#
# [5 rows x 30 columns]

# %%
# set index to geo id
ft2015_df = features_2015.set_index('GEO_ID2015')
ft2015_df.head()
# Out:
#                       Unnamed: 0  STATE2015  \
# GEO_ID2015
# 1400000US01097006501           1          1
# 1400000US01097006502           2          1
# 1400000US01097006600           3          1
# 1400000US01097006701           4          1
# 1400000US01097006702           5          1
#
#                                                         NAME2015  \
# GEO_ID2015
# 1400000US01097006501  Census Tract 65.01, Mobile County, Alabama
# 1400000US01097006502  Census Tract 65.02, Mobile County, Alabama
# 1400000US01097006600     Census Tract 66, Mobile County, Alabama
# 1400000US01097006701  Census Tract 67.01, Mobile County, Alabama
# 1400000US01097006702  Census Tract 67.02, Mobile County, Alabama
#
#                       B01001_001E2015  B01001_002E2015  B01001_026E2015  \
# GEO_ID2015
# 1400000US01097006501             5143             2180             2963
# 1400000US01097006502            11578             5705             5873
# 1400000US01097006600             5574             2788             2786
# 1400000US01097006701             6436             3174             3262
# 1400000US01097006702             3270             1564             1706
#
#                       B01002_001E2015  B01003_001E2015  B19037_001E2015  \
# GEO_ID2015
# 1400000US01097006501             39.0             5143             1785
# 1400000US01097006502             37.6            11578             4018
# 1400000US01097006600             38.9             5574             1867
# 1400000US01097006701             39.8             6436             2404
# 1400000US01097006702             39.0             3270             1266
#
#                       B19001_001E2015  ...  B19301_001E2015  B19131_002E2015  \
# GEO_ID2015                             ...
# 1400000US01097006501             1785  ...          22679.0             1005
# 1400000US01097006502             4018  ...          26159.0             2718
# 1400000US01097006600             1867  ...          21728.0             1083
# 1400000US01097006701             2404  ...          19367.0             1246
# 1400000US01097006702             1266  ...          18702.0              571
#
#                       B19131_003E2015  B19126_001E2015  B03002_009E2015  \
# GEO_ID2015
# 1400000US01097006501              382          61619.0              179
# 1400000US01097006502             1329              NaN              158
# 1400000US01097006600              408              NaN                0
# 1400000US01097006701              594          45335.0              201
# 1400000US01097006702              127          46875.0              107
#
#                       B03002_010E2015  B03002_011E2015  state2015  county2015  \
# GEO_ID2015
# 1400000US01097006501                0              179          1          97
# 1400000US01097006502                0              158          1          97
# 1400000US01097006600                0                0          1          97
# 1400000US01097006701                0              201          1          97
# 1400000US01097006702                0              107          1          97
#
#                       tract2015
# GEO_ID2015
# 1400000US01097006501       6501
# 1400000US01097006502       6502
# 1400000US01097006600       6600
# 1400000US01097006701       6701
# 1400000US01097006702       6702
#
# [5 rows x 30 columns]

# %%
# merge 2010 and 2015 features to usda data 
all_features = ft2010_df.merge(ft2015_df, left_index = True, right_index= True)

# %%
all_features.columns
# Out:
# Index(['Unnamed: 0_x', 'STATE2010', 'NAME2010', 'B01001_001E2010',
#        'B01001_002E2010', 'B01001_026E2010', 'B01002_001E2010',
#        'B01003_001E2010', 'B19037_001E2010', 'B19001_001E2010',
#        'B17023_001E2010', 'B17020A_014E2010', 'B08303_002E2010',
#        'B08303_010E2010', 'B08301_010E2010', 'B08301_002E2010',
#        'B08202_004E2010', 'B08202_020E2010', 'B08137_002E2010',
#        'B19326_001E2010', 'B19301_001E2010', 'B19131_002E2010',
#        'B19131_003E2010', 'B19126_001E2010', 'B03002_009E2010',
#        'B03002_010E2010', 'B03002_011E2010', 'state2010', 'county2010',
#        'tract2010', 'Unnamed: 0_y', 'STATE2015', 'NAME2015', 'B01001_001E2015',
#        'B01001_002E2015', 'B01001_026E2015', 'B01002_001E2015',
#        'B01003_001E2015', 'B19037_001E2015', 'B19001_001E2015',
#        'B17023_001E2015', 'B17020A_014E2015', 'B08303_002E2015',
#        'B08303_010E2015', 'B08301_010E2015', 'B08301_002E2015',
#        'B08202_004E2015', 'B08202_020E2015', 'B08137_002E2015',
#        'B19326_001E2015', 'B19301_001E2015', 'B19131_002E2015',
#        'B19131_003E2015', 'B19126_001E2015', 'B03002_009E2015',
#        'B03002_010E2015', 'B03002_011E2015', 'state2015', 'county2015',
#        'tract2015'],
#       dtype='object')

# %%
all_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 71483 entries, 1400000US01001020100 to 1400000US51840000302
# Data columns (total 60 columns):
# Unnamed: 0_x        71483 non-null int64
# STATE2010           71483 non-null int64
# NAME2010            71483 non-null object
# B01001_001E2010     71483 non-null int64
# B01001_002E2010     71483 non-null int64
# B01001_026E2010     71483 non-null int64
# B01002_001E2010     71483 non-null float64
# B01003_001E2010     71483 non-null int64
# B19037_001E2010     71483 non-null int64
# B19001_001E2010     71483 non-null int64
# B17023_001E2010     71483 non-null int64
# B17020A_014E2010    71483 non-null int64
# B08303_002E2010     71483 non-null int64
# B08303_010E2010     71483 non-null int64
# B08301_010E2010     71483 non-null int64
# B08301_002E2010     71483 non-null int64
# B08202_004E2010     71483 non-null int64
# B08202_020E2010     71483 non-null int64
# B08137_002E2010     71483 non-null int64
# B19326_001E2010     71483 non-null int64
# B19301_001E2010     71446 non-null float64
# B19131_002E2010     71483 non-null int64
# B19131_003E2010     71483 non-null int64
# B19126_001E2010     71483 non-null int64
# B03002_009E2010     71483 non-null int64
# B03002_010E2010     71483 non-null int64
# B03002_011E2010     71483 non-null int64
# state2010           71483 non-null int64
# county2010          71483 non-null int64
# tract2010           71483 non-null int64
# Unnamed: 0_y        71483 non-null int64
# STATE2015           71483 non-null int64
# NAME2015            71483 non-null object
# B01001_001E2015     71483 non-null int64
# B01001_002E2015     71483 non-null int64
# B01001_026E2015     71483 non-null int64
# B01002_001E2015     71483 non-null float64
# B01003_001E2015     71483 non-null int64
# B19037_001E2015     71483 non-null int64
# B19001_001E2015     71483 non-null int64
# B17023_001E2015     71483 non-null int64
# B17020A_014E2015    71483 non-null int64
# B08303_002E2015     71483 non-null int64
# B08303_010E2015     71483 non-null int64
# B08301_010E2015     71483 non-null int64
# B08301_002E2015     71483 non-null int64
# B08202_004E2015     71483 non-null int64
# B08202_020E2015     71483 non-null int64
# B08137_002E2015     71483 non-null int64
# B19326_001E2015     69394 non-null float64
# B19301_001E2015     71434 non-null float64
# B19131_002E2015     71483 non-null int64
# B19131_003E2015     71483 non-null int64
# B19126_001E2015     20877 non-null float64
# B03002_009E2015     71483 non-null int64
# B03002_010E2015     71483 non-null int64
# B03002_011E2015     71483 non-null int64
# state2015           71483 non-null int64
# county2015          71483 non-null int64
# tract2015           71483 non-null int64
# dtypes: float64(6), int64(52), object(2)
# memory usage: 33.3+ MB

# %%
# merge features to usda dataset
all_ft_df = usda_df.merge(all_features, how='inner', left_index = True, right_index = True)

# %%
all_ft_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 64573 entries, 1400000US02013000100 to 1400000US50027966700
# Data columns (total 91 columns):
# CensusTract                  64573 non-null int64
# State_x                      64573 non-null object
# HUNVFlag_x                   64573 non-null int64
# LILATracts_1And10_x          64573 non-null int64
# LILATracts_halfAnd10_x       64573 non-null int64
# LILATracts_Vehicle_x         64573 non-null int64
# LATracts1_y                  64573 non-null int64
# LATracts10_y                 64573 non-null int64
# LATracts20_y                 64573 non-null int64
# LATracts_half_y              64573 non-null int64
# LATracts1_x                  64573 non-null int64
# LATracts10_x                 64573 non-null int64
# LATracts20_x                 64573 non-null int64
# LATracts_half_x              64573 non-null int64
# LILATracts_1And20_x          64573 non-null int64
# HUNVFlag_y                   64573 non-null int64
# LILATracts_1And10_y          64573 non-null int64
# LILATracts_halfAnd10_y       64573 non-null int64
# LILATracts_Vehicle_y         64573 non-null int64
# LILATracts_1And20_y          64573 non-null int64
# entropy_index10_y            64573 non-null float64
# entropy_index15_x            64573 non-null float64
# HUNVFlag_diff                64573 non-null int64
# LILATracts_1And10_diff       64573 non-null int64
# LILATracts_halfAnd10_diff    64573 non-null int64
# LILATracts_Vehicle_diff      64573 non-null int64
# LILATracts_1And20_diff       64573 non-null int64
# LATracts1_diff               64573 non-null int64
# LATracts10_diff              64573 non-null int64
# LATracts20_diff              64573 non-null int64
# LATracts_half_diff           64573 non-null int64
# Unnamed: 0_x                 64573 non-null int64
# STATE2010                    64573 non-null int64
# NAME2010                     64573 non-null object
# B01001_001E2010              64573 non-null int64
# B01001_002E2010              64573 non-null int64
# B01001_026E2010              64573 non-null int64
# B01002_001E2010              64573 non-null float64
# B01003_001E2010              64573 non-null int64
# B19037_001E2010              64573 non-null int64
# B19001_001E2010              64573 non-null int64
# B17023_001E2010              64573 non-null int64
# B17020A_014E2010             64573 non-null int64
# B08303_002E2010              64573 non-null int64
# B08303_010E2010              64573 non-null int64
# B08301_010E2010              64573 non-null int64
# B08301_002E2010              64573 non-null int64
# B08202_004E2010              64573 non-null int64
# B08202_020E2010              64573 non-null int64
# B08137_002E2010              64573 non-null int64
# B19326_001E2010              64573 non-null int64
# B19301_001E2010              64572 non-null float64
# B19131_002E2010              64573 non-null int64
# B19131_003E2010              64573 non-null int64
# B19126_001E2010              64573 non-null int64
# B03002_009E2010              64573 non-null int64
# B03002_010E2010              64573 non-null int64
# B03002_011E2010              64573 non-null int64
# state2010                    64573 non-null int64
# county2010                   64573 non-null int64
# tract2010                    64573 non-null int64
# Unnamed: 0_y                 64573 non-null int64
# STATE2015                    64573 non-null int64
# NAME2015                     64573 non-null object
# B01001_001E2015              64573 non-null int64
# B01001_002E2015              64573 non-null int64
# B01001_026E2015              64573 non-null int64
# B01002_001E2015              64573 non-null float64
# B01003_001E2015              64573 non-null int64
# B19037_001E2015              64573 non-null int64
# B19001_001E2015              64573 non-null int64
# B17023_001E2015              64573 non-null int64
# B17020A_014E2015             64573 non-null int64
# B08303_002E2015              64573 non-null int64
# B08303_010E2015              64573 non-null int64
# B08301_010E2015              64573 non-null int64
# B08301_002E2015              64573 non-null int64
# B08202_004E2015              64573 non-null int64
# B08202_020E2015              64573 non-null int64
# B08137_002E2015              64573 non-null int64
# B19326_001E2015              62809 non-null float64
# B19301_001E2015              64572 non-null float64
# B19131_002E2015              64573 non-null int64
# B19131_003E2015              64573 non-null int64
# B19126_001E2015              18371 non-null float64
# B03002_009E2015              64573 non-null int64
# B03002_010E2015              64573 non-null int64
# B03002_011E2015              64573 non-null int64
# state2015                    64573 non-null int64
# county2015                   64573 non-null int64
# tract2015                    64573 non-null int64
# dtypes: float64(8), int64(80), object(3)
# memory usage: 45.3+ MB

# %%
all_ft_df.columns
# Out:
# Index(['CensusTract', 'State_x', 'HUNVFlag_x', 'LILATracts_1And10_x',
#        'LILATracts_halfAnd10_x', 'LILATracts_Vehicle_x', 'LATracts1_y',
#        'LATracts10_y', 'LATracts20_y', 'LATracts_half_y', 'LATracts1_x',
#        'LATracts10_x', 'LATracts20_x', 'LATracts_half_x',
#        'LILATracts_1And20_x', 'HUNVFlag_y', 'LILATracts_1And10_y',
#        'LILATracts_halfAnd10_y', 'LILATracts_Vehicle_y', 'LILATracts_1And20_y',
#        'entropy_index10_y', 'entropy_index15_x', 'HUNVFlag_diff',
#        'LILATracts_1And10_diff', 'LILATracts_halfAnd10_diff',
#        'LILATracts_Vehicle_diff', 'LILATracts_1And20_diff', 'LATracts1_diff',
#        'LATracts10_diff', 'LATracts20_diff', 'LATracts_half_diff',
#        'Unnamed: 0_x', 'STATE2010', 'NAME2010', 'B01001_001E2010',
#        'B01001_002E2010', 'B01001_026E2010', 'B01002_001E2010',
#        'B01003_001E2010', 'B19037_001E2010', 'B19001_001E2010',
#        'B17023_001E2010', 'B17020A_014E2010', 'B08303_002E2010',
#        'B08303_010E2010', 'B08301_010E2010', 'B08301_002E2010',
#        'B08202_004E2010', 'B08202_020E2010', 'B08137_002E2010',
#        'B19326_001E2010', 'B19301_001E2010', 'B19131_002E2010',
#        'B19131_003E2010', 'B19126_001E2010', 'B03002_009E2010',
#        'B03002_010E2010', 'B03002_011E2010', 'state2010', 'county2010',
#        'tract2010', 'Unnamed: 0_y', 'STATE2015', 'NAME2015', 'B01001_001E2015',
#        'B01001_002E2015', 'B01001_026E2015', 'B01002_001E2015',
#        'B01003_001E2015', 'B19037_001E2015', 'B19001_001E2015',
#        'B17023_001E2015', 'B17020A_014E2015', 'B08303_002E2015',
#        'B08303_010E2015', 'B08301_010E2015', 'B08301_002E2015',
#        'B08202_004E2015', 'B08202_020E2015', 'B08137_002E2015',
#        'B19326_001E2015', 'B19301_001E2015', 'B19131_002E2015',
#        'B19131_003E2015', 'B19126_001E2015', 'B03002_009E2015',
#        'B03002_010E2015', 'B03002_011E2015', 'state2015', 'county2015',
#        'tract2015', 'B01001_001E'],
#       dtype='object')

# %%
# get the differences in features 
all_ft_df['B01001_001E_diff'] = all_ft_df['B01001_001E2015'] - all_ft_df['B01001_001E2010']
all_ft_df['B01001_002E_diff'] = all_ft_df['B01001_002E2015'] - all_ft_df['B01001_002E2010']
all_ft_df['B01001_026E_diff'] = all_ft_df['B01001_026E2015'] - all_ft_df['B01001_026E2010']
all_ft_df['B01002_001E_diff'] = all_ft_df['B01002_001E2015'] - all_ft_df['B01002_001E2010']
all_ft_df['B01003_001E_diff'] = all_ft_df['B01003_001E2015'] - all_ft_df['B01003_001E2010']
all_ft_df['B19037_001E_diff'] = all_ft_df['B19037_001E2015'] - all_ft_df['B19037_001E2010']
all_ft_df['B19001_001E_diff'] = all_ft_df['B19001_001E2015'] - all_ft_df['B19001_001E2010']
all_ft_df['B17023_001E_diff'] = all_ft_df['B17023_001E2015'] - all_ft_df['B17023_001E2010']
all_ft_df['B17020A_014E_diff'] = all_ft_df['B17020A_014E2015'] - all_ft_df['B17020A_014E2010']
all_ft_df['B08303_002E_diff'] = all_ft_df['B08303_002E2015'] - all_ft_df['B08303_002E2010']
all_ft_df['B08303_010E_diff'] = all_ft_df['B08303_010E2015'] - all_ft_df['B08303_010E2010']
all_ft_df['B08301_010E_diff'] = all_ft_df['B08301_010E2015'] - all_ft_df['B08301_010E2010']
all_ft_df['B08301_002E_diff'] = all_ft_df['B08301_002E2015'] - all_ft_df['B08301_002E2010']
all_ft_df['B08202_004E_diff'] = all_ft_df['B08202_004E2015'] - all_ft_df['B08202_004E2010']
all_ft_df['B08202_020E_diff'] = all_ft_df['B08202_020E2015'] - all_ft_df['B08202_020E2010']
all_ft_df['B08137_002E_diff'] = all_ft_df['B08137_002E2015'] - all_ft_df['B08137_002E2010']
all_ft_df['B19326_001E_diff'] = all_ft_df['B19326_001E2015'] - all_ft_df['B19326_001E2010']
all_ft_df['B19301_001E_diff'] = all_ft_df['B19301_001E2015'] - all_ft_df['B19301_001E2010']
all_ft_df['B19131_002E_diff'] = all_ft_df['B19131_002E2015'] - all_ft_df['B19131_002E2010']
all_ft_df['B19131_003E_diff'] = all_ft_df['B19131_003E2015'] - all_ft_df['B19131_003E2010']
all_ft_df['B19126_001E_diff'] = all_ft_df['B19126_001E2015'] - all_ft_df['B19126_001E2010']
all_ft_df['B03002_009E_diff'] = all_ft_df['B03002_009E2015'] - all_ft_df['B03002_009E2010']
all_ft_df['B03002_010E_diff'] = all_ft_df['B03002_010E2015'] - all_ft_df['B03002_010E2010']
all_ft_df['B03002_011E_diff'] = all_ft_df['B03002_011E2015'] - all_ft_df['B03002_011E2010']

# %%
# check new cols were added
list(all_ft_df.columns)
# Out:
# ['CensusTract',
#  'State_x',
#  'HUNVFlag_x',
#  'LILATracts_1And10_x',
#  'LILATracts_halfAnd10_x',
#  'LILATracts_Vehicle_x',
#  'LATracts1_y',
#  'LATracts10_y',
#  'LATracts20_y',
#  'LATracts_half_y',
#  'LATracts1_x',
#  'LATracts10_x',
#  'LATracts20_x',
#  'LATracts_half_x',
#  'LILATracts_1And20_x',
#  'HUNVFlag_y',
#  'LILATracts_1And10_y',
#  'LILATracts_halfAnd10_y',
#  'LILATracts_Vehicle_y',
#  'LILATracts_1And20_y',
#  'entropy_index10_y',
#  'entropy_index15_x',
#  'HUNVFlag_diff',
#  'LILATracts_1And10_diff',
#  'LILATracts_halfAnd10_diff',
#  'LILATracts_Vehicle_diff',
#  'LILATracts_1And20_diff',
#  'LATracts1_diff',
#  'LATracts10_diff',
#  'LATracts20_diff',
#  'LATracts_half_diff',
#  'Unnamed: 0_x',
#  'STATE2010',
#  'NAME2010',
#  'B01001_001E2010',
#  'B01001_002E2010',
#  'B01001_026E2010',
#  'B01002_001E2010',
#  'B01003_001E2010',
#  'B19037_001E2010',
#  'B19001_001E2010',
#  'B17023_001E2010',
#  'B17020A_014E2010',
#  'B08303_002E2010',
#  'B08303_010E2010',
#  'B08301_010E2010',
#  'B08301_002E2010',
#  'B08202_004E2010',
#  'B08202_020E2010',
#  'B08137_002E2010',
#  'B19326_001E2010',
#  'B19301_001E2010',
#  'B19131_002E2010',
#  'B19131_003E2010',
#  'B19126_001E2010',
#  'B03002_009E2010',
#  'B03002_010E2010',
#  'B03002_011E2010',
#  'state2010',
#  'county2010',
#  'tract2010',
#  'Unnamed: 0_y',
#  'STATE2015',
#  'NAME2015',
#  'B01001_001E2015',
#  'B01001_002E2015',
#  'B01001_026E2015',
#  'B01002_001E2015',
#  'B01003_001E2015',
#  'B19037_001E2015',
#  'B19001_001E2015',
#  'B17023_001E2015',
#  'B17020A_014E2015',
#  'B08303_002E2015',
#  'B08303_010E2015',
#  'B08301_010E2015',
#  'B08301_002E2015',
#  'B08202_004E2015',
#  'B08202_020E2015',
#  'B08137_002E2015',
#  'B19326_001E2015',
#  'B19301_001E2015',
#  'B19131_002E2015',
#  'B19131_003E2015',
#  'B19126_001E2015',
#  'B03002_009E2015',
#  'B03002_010E2015',
#  'B03002_011E2015',
#  'state2015',
#  'county2015',
#  'tract2015',
#  'B01001_001E',
#  'B01001_001E_diff',
#  'B01001_002E_diff',
#  'B01001_026E_diff',
#  'B01002_001E_diff',
#  'B01003_001E_diff',
#  'B19037_001E_diff',
#  'B19001_001E_diff',
#  'B17023_001E_diff',
#  'B17020A_014E_diff',
#  'B08303_002E_diff',
#  'B08303_010E_diff',
#  'B08301_010E_diff',
#  'B08301_002E_diff',
#  'B08202_004E_diff',
#  'B08202_020E_diff',
#  'B08137_002E_diff',
#  'B19326_001E_diff',
#  'B19301_001E_diff',
#  'B19131_002E_diff',
#  'B19131_003E_diff',
#  'B19126_001E_diff',
#  'B03002_009E_diff',
#  'B03002_010E_diff',
#  'B03002_011E_diff']

# %%
# read to csv 
all_ft_df.to_csv('all_features_by_state.csv')
