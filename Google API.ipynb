# %%
import json
import requests
from bs4 import BeautifulSoup
import pandas as pd
from IPython.display import display
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# # Interfacing with Google Places and Photos API
#
# This notebook is used to interface with Google Places and Photos API to fetch location/place and related photos information.
#
# This information shall be used to create our Baseline Recommendation System.
#
# Dependent googlemaps library needs to be installed and also related API Key needs to be obtained.

# %%
# Install googlemaps library
# !pip install googlemaps

import googlemaps

# Define the Google API Key
API_KEY = 'AIzaSyAm83eARS6kSoB1ZN3P0fqf9p8QP0VzmIY'
# Out:
# Requirement already satisfied: googlemaps in /opt/conda/lib/python3.6/site-packages (4.4.2)
# Requirement already satisfied: requests<3.0,>=2.20.0 in /opt/conda/lib/python3.6/site-packages (from googlemaps) (2.21.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/lib/python3.6/site-packages (from requests<3.0,>=2.20.0->googlemaps) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/lib/python3.6/site-packages (from requests<3.0,>=2.20.0->googlemaps) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.6/site-packages (from requests<3.0,>=2.20.0->googlemaps) (2018.11.29)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /opt/conda/lib/python3.6/site-packages (from requests<3.0,>=2.20.0->googlemaps) (1.24.1)

# %%
# Initializing client
gmaps = googlemaps.Client(key= API_KEY)

# %% [markdown]
# ### Find places by name
# For generic names this API returns more than one result and for specific name returns exact matching result.
#
# This is illustrated with search to Burger King which finds 20 places. But search for Status of Liberty gives back only one result.

# %%
def find_place(input):
    my_fields = ['name','photos', 'place_id', 'types','formatted_address']
    place_results = gmaps.places(query=input)
    return place_results

# %%
places = find_place('grocery stores in washington dc')['results']
print(f"Search result count: {len(places)}")
places[0:2]
places = pd.DataFrame(places)
places
# Out:
# Search result count: 20
#    business_status                                  formatted_address  \
# 0      OPERATIONAL  1231 11th St NW, Washington, DC 20001, United ...
# 1      OPERATIONAL  3178 Mt Pleasant St NW, Washington, DC 20010, ...
# 2      OPERATIONAL  1440 P St NW, Washington, DC 20005, United States
# 3      OPERATIONAL  2130 P St NW #5, Washington, DC 20037, United ...
# 4      OPERATIONAL  241 Massachusetts Ave NE, Washington, DC 20002...
# 5      OPERATIONAL  539 8th St NE, Washington, DC 20002, United St...
# 6      OPERATIONAL  3830 Georgia Ave NW, Washington, DC 20011, Uni...
# 7      OPERATIONAL  2006 Rhode Island Ave NE, Washington, DC 20018...
# 8      OPERATIONAL  1221 Massachusetts Ave NW, Washington, DC 2000...
# 9      OPERATIONAL  2001 S St NW, Washington, DC 20009, United States
# 10     OPERATIONAL  1855 Wisconsin Ave NW, Washington, DC 20007, U...
# 11     OPERATIONAL   490 L St NW, Washington, DC 20001, United States
# 12     OPERATIONAL  1717 Connecticut Ave NW, Washington, DC 20009,...
# 13     OPERATIONAL  1914 14th St NW, Washington, DC 20009, United ...
# 14     OPERATIONAL  1101 25th St NW, Washington, DC 20037, United ...
# 15     OPERATIONAL  1701 Corcoran St NW, Washington, DC 20009, Uni...
# 16     OPERATIONAL  400 East Capitol St NE, Washington, DC 20003, ...
# 17     OPERATIONAL  2833 11th St NW, Washington, DC 20001, United ...
# 18     OPERATIONAL  100 Kennedy St NW, Washington, DC 20011, Unite...
# 19     OPERATIONAL  1201 Mt Olivet Rd NE, Washington, DC 20002, Un...
#
#                                              geometry  \
# 0   {'location': {'lat': 38.9068776, 'lng': -77.02...
# 1   {'location': {'lat': 38.930875, 'lng': -77.038...
# 2   {'location': {'lat': 38.9092854, 'lng': -77.03...
# 3   {'location': {'lat': 38.9094279, 'lng': -77.04...
# 4   {'location': {'lat': 38.894409, 'lng': -77.002...
# 5   {'location': {'lat': 38.8971731, 'lng': -76.99...
# 6   {'location': {'lat': 38.9384858, 'lng': -77.02...
# 7   {'location': {'lat': 38.9295176, 'lng': -76.97...
# 8   {'location': {'lat': 38.9050153, 'lng': -77.02...
# 9   {'location': {'lat': 38.9144181, 'lng': -77.04...
# 10  {'location': {'lat': 38.9160652, 'lng': -77.06...
# 11  {'location': {'lat': 38.9035684, 'lng': -77.01...
# 12  {'location': {'lat': 38.9132, 'lng': -77.04520...
# 13  {'location': {'lat': 38.9160454, 'lng': -77.03...
# 14  {'location': {'lat': 38.90409289999999, 'lng':...
# 15  {'location': {'lat': 38.9119596, 'lng': -77.03...
# 16  {'location': {'lat': 38.890097, 'lng': -77.000...
# 17  {'location': {'lat': 38.9266744, 'lng': -77.02...
# 18  {'location': {'lat': 38.9563838, 'lng': -77.01...
# 19  {'location': {'lat': 38.9098422, 'lng': -76.98...
#
#                                                  icon  \
# 0   https://maps.gstatic.com/mapfiles/place_api/ic...
# 1   https://maps.gstatic.com/mapfiles/place_api/ic...
# 2   https://maps.gstatic.com/mapfiles/place_api/ic...
# 3   https://maps.gstatic.com/mapfiles/place_api/ic...
# 4   https://maps.gstatic.com/mapfiles/place_api/ic...
# 5   https://maps.gstatic.com/mapfiles/place_api/ic...
# 6   https://maps.gstatic.com/mapfiles/place_api/ic...
# 7   https://maps.gstatic.com/mapfiles/place_api/ic...
# 8   https://maps.gstatic.com/mapfiles/place_api/ic...
# 9   https://maps.gstatic.com/mapfiles/place_api/ic...
# 10  https://maps.gstatic.com/mapfiles/place_api/ic...
# 11  https://maps.gstatic.com/mapfiles/place_api/ic...
# 12  https://maps.gstatic.com/mapfiles/place_api/ic...
# 13  https://maps.gstatic.com/mapfiles/place_api/ic...
# 14  https://maps.gstatic.com/mapfiles/place_api/ic...
# 15  https://maps.gstatic.com/mapfiles/place_api/ic...
# 16  https://maps.gstatic.com/mapfiles/place_api/ic...
# 17  https://maps.gstatic.com/mapfiles/place_api/ic...
# 18  https://maps.gstatic.com/mapfiles/place_api/ic...
# 19  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                                     name        opening_hours  \
# 0                    Capitol Supermarket   {'open_now': True}
# 1                  BestWorld Supermarket   {'open_now': True}
# 2                     Whole Foods Market   {'open_now': True}
# 3                      Metro Supermarket   {'open_now': True}
# 4               Capitol Hill Supermarket   {'open_now': True}
# 5                         DC Supermarket   {'open_now': True}
# 6                                Safeway   {'open_now': True}
# 7                      Good Food Markets   {'open_now': True}
# 8                         Streets Market   {'open_now': True}
# 9                   Glen's Garden Market   {'open_now': True}
# 10                               Safeway   {'open_now': True}
# 11                               Safeway   {'open_now': True}
# 12  The Mediterranean Way Gourmet Market  {'open_now': False}
# 13                          Trader Joe's   {'open_now': True}
# 14                          Trader Joe's   {'open_now': True}
# 15                               Safeway   {'open_now': True}
# 16                     The Corner Market   {'open_now': True}
# 17                        Sonya's Market   {'open_now': True}
# 18                Brightwood Supermarket   {'open_now': True}
# 19                 Northeast Supermarket   {'open_now': True}
#
#                                                photos  \
# 0   [{'height': 4032, 'html_attributions': ['<a hr...
# 1   [{'height': 4032, 'html_attributions': ['<a hr...
# 2   [{'height': 3000, 'html_attributions': ['<a hr...
# 3   [{'height': 2988, 'html_attributions': ['<a hr...
# 4   [{'height': 2268, 'html_attributions': ['<a hr...
# 5   [{'height': 4032, 'html_attributions': ['<a hr...
# 6   [{'height': 1080, 'html_attributions': ['<a hr...
# 7   [{'height': 3036, 'html_attributions': ['<a hr...
# 8   [{'height': 3024, 'html_attributions': ['<a hr...
# 9   [{'height': 4032, 'html_attributions': ['<a hr...
# 10  [{'height': 3024, 'html_attributions': ['<a hr...
# 11  [{'height': 4608, 'html_attributions': ['<a hr...
# 12  [{'height': 4032, 'html_attributions': ['<a hr...
# 13  [{'height': 3036, 'html_attributions': ['<a hr...
# 14  [{'height': 3264, 'html_attributions': ['<a hr...
# 15  [{'height': 5248, 'html_attributions': ['<a hr...
# 16  [{'height': 3024, 'html_attributions': ['<a hr...
# 17  [{'height': 4048, 'html_attributions': ['<a hr...
# 18  [{'height': 3024, 'html_attributions': ['<a hr...
# 19  [{'height': 2560, 'html_attributions': ['<a hr...
#
#                        place_id  \
# 0   ChIJM23Hluy3t4kRLGK6yEyUqf4
# 1   ChIJ80jrNyHIt4kRf9zX1J6dKKg
# 2   ChIJE_Jo2MG3t4kRDmuaghjExpo
# 3   ChIJRy9DsMm3t4kR1FwU13J8DRs
# 4   ChIJ0SxnriW4t4kRwq_acre2ilA
# 5   ChIJ55r7cTy4t4kR6Q3XdpBbopE
# 6   ChIJFYjvVhDIt4kRL8_zYyRLq5Y
# 7   ChIJf0h8WIXHt4kRw4PmMyqd3Fs
# 8   ChIJz7YstpS3t4kR-yx-siu2Q2Y
# 9   ChIJE8m5Ys-3t4kRDLep_4lRvVY
# 10  ChIJ5XC3pjC2t4kRq8j9l30w0M4
# 11  ChIJU1CkyIy3t4kRa6gfvF_84DA
# 12  ChIJOVTbVs-3t4kRVhl8QWo3wvo
# 13  ChIJH1DN5ue3t4kRKd3OmU-YQUQ
# 14  ChIJPWlbYbS3t4kRJFvl1URXiSw
# 15  ChIJt1kZ_MO3t4kRGnBmJWS1cMA
# 16  ChIJsW2Fty-4t4kRUcLBS7rMIeo
# 17  ChIJRb4Y7x3It4kRdRTQIA8Frnw
# 18  ChIJlQt1anjIt4kR_iyyY5esNu4
# 19  ChIJNz9UcW24t4kRoOY_DATJXH0
#
#                                             plus_code  price_level  rating  \
# 0   {'compound_code': 'WX4F+Q7 Washington, Distric...          NaN     4.0
# 1   {'compound_code': 'WXJ6+9H Washington, Distric...          NaN     4.2
# 2   {'compound_code': 'WX58+PH Washington, Distric...          3.0     4.3
# 3   {'compound_code': 'WX52+QR Washington, Distric...          NaN     3.9
# 4   {'compound_code': 'VXVX+Q3 Washington, Distric...          NaN     4.3
# 5   {'compound_code': 'V2W4+V4 Washington, Distric...          NaN     3.1
# 6   {'compound_code': 'WXQG+92 Washington, Distric...          2.0     4.1
# 7   {'compound_code': 'W2HF+RM Washington, Distric...          NaN     4.5
# 8   {'compound_code': 'WX4C+27 Washington, Distric...          NaN     4.3
# 9   {'compound_code': 'WX73+QW Washington, Distric...          2.0     4.6
# 10  {'compound_code': 'WW8M+C4 Washington, Distric...          2.0     4.1
# 11  {'compound_code': 'WX3J+CG Washington, Distric...          2.0     3.7
# 12  {'compound_code': 'WX73+7W Washington, Distric...          2.0     4.5
# 13  {'compound_code': 'WX89+C4 Washington, Distric...          2.0     4.6
# 14  {'compound_code': 'WW3W+JQ Washington, Distric...          2.0     4.6
# 15  {'compound_code': 'WX66+QG Washington, Distric...          2.0     3.5
# 16  {'compound_code': 'VXRX+2V Washington, Distric...          NaN     3.8
# 17  {'compound_code': 'WXGF+M7 Washington, Distric...          NaN     4.5
# 18  {'compound_code': 'XX4Q+H7 Washington, Distric...          NaN     4.3
# 19  {'compound_code': 'W258+W3 Washington, Distric...          NaN     3.8
#
#                       reference  \
# 0   ChIJM23Hluy3t4kRLGK6yEyUqf4
# 1   ChIJ80jrNyHIt4kRf9zX1J6dKKg
# 2   ChIJE_Jo2MG3t4kRDmuaghjExpo
# 3   ChIJRy9DsMm3t4kR1FwU13J8DRs
# 4   ChIJ0SxnriW4t4kRwq_acre2ilA
# 5   ChIJ55r7cTy4t4kR6Q3XdpBbopE
# 6   ChIJFYjvVhDIt4kRL8_zYyRLq5Y
# 7   ChIJf0h8WIXHt4kRw4PmMyqd3Fs
# 8   ChIJz7YstpS3t4kR-yx-siu2Q2Y
# 9   ChIJE8m5Ys-3t4kRDLep_4lRvVY
# 10  ChIJ5XC3pjC2t4kRq8j9l30w0M4
# 11  ChIJU1CkyIy3t4kRa6gfvF_84DA
# 12  ChIJOVTbVs-3t4kRVhl8QWo3wvo
# 13  ChIJH1DN5ue3t4kRKd3OmU-YQUQ
# 14  ChIJPWlbYbS3t4kRJFvl1URXiSw
# 15  ChIJt1kZ_MO3t4kRGnBmJWS1cMA
# 16  ChIJsW2Fty-4t4kRUcLBS7rMIeo
# 17  ChIJRb4Y7x3It4kRdRTQIA8Frnw
# 18  ChIJlQt1anjIt4kR_iyyY5esNu4
# 19  ChIJNz9UcW24t4kRoOY_DATJXH0
#
#                                                 types  user_ratings_total
# 0   [supermarket, grocery_or_supermarket, food, po...                 264
# 1   [supermarket, grocery_or_supermarket, food, po...                 124
# 2   [grocery_or_supermarket, supermarket, food, he...                1723
# 3   [supermarket, grocery_or_supermarket, food, po...                  92
# 4   [supermarket, grocery_or_supermarket, food, po...                 149
# 5   [convenience_store, supermarket, grocery_or_su...                   8
# 6   [grocery_or_supermarket, food, point_of_intere...                1376
# 7   [grocery_or_supermarket, supermarket, liquor_s...                 200
# 8   [grocery_or_supermarket, supermarket, liquor_s...                 298
# 9   [grocery_or_supermarket, cafe, bar, food, poin...                 623
# 10  [grocery_or_supermarket, food, point_of_intere...                 904
# 11  [grocery_or_supermarket, food, point_of_intere...                 956
# 12  [grocery_or_supermarket, food, point_of_intere...                  30
# 13  [grocery_or_supermarket, florist, supermarket,...                1817
# 14  [grocery_or_supermarket, florist, supermarket,...                1253
# 15  [grocery_or_supermarket, food, point_of_intere...                 663
# 16  [grocery_or_supermarket, convenience_store, li...                  16
# 17  [supermarket, grocery_or_supermarket, food, po...                  44
# 18  [grocery_or_supermarket, supermarket, liquor_s...                  32
# 19  [supermarket, grocery_or_supermarket, food, po...                 112

# %%
places = find_place('Status of Liberty')['results']
print(f"Search result count: {len(places)}")
places
# Out:
# Search result count: 1
# [{'business_status': 'OPERATIONAL',
#   'formatted_address': 'New York, NY 10004, United States',
#   'geometry': {'location': {'lat': 40.6892494, 'lng': -74.04450039999999},
#    'viewport': {'northeast': {'lat': 40.71814749999999,
#      'lng': -73.99872490000001},
#     'southwest': {'lat': 40.6796167, 'lng': -74.05975889999998}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'name': 'Statue of Liberty National Monument',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 4000,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105303505373661530610">Hauser Quaid Zzyzx</a>'],
#     'photo_reference': 'ATtYBwIFiFm9sujTiQGD9vj4cTWYsGpdgoAjYyDsEe0Q3S8WEUsF5_kTndJzR_ZU_SsyPBgQ5AuQycnPPhwUU3rNf7DtwRbnz5rbA4a0hnzRdNZXQe463Ay7SLh7D0s2RWGDe8FuWKEtS_qHeVwGIYJ2o-V1gHSA49tkw2wrhKRH1PjM-y15',
#     'width': 6000}],
#   'place_id': 'ChIJPTacEpBQwokRKwIlDXelxkA',
#   'plus_code': {'compound_code': 'MXQ4+M5 New York',
#    'global_code': '87G7MXQ4+M5'},
#   'rating': 4.7,
#   'reference': 'ChIJPTacEpBQwokRKwIlDXelxkA',
#   'types': ['tourist_attraction',
#    'park',
#    'point_of_interest',
#    'establishment'],
#   'user_ratings_total': 72809}]

# %% [markdown]
# ### Get Places Details
# Result for googlemaps.places API includes place_id. place_id is an unique identifier for each location/place. With this place_id, we can get detailed information about the location/place using googlemaps.place API.
#
# Places Details contains key information like address, photos, type and others which can be used for building the Recommendation System.

# %%
gmaps.place('ChIJPTacEpBQwokRKwIlDXelxkA')
# Out:
# {'html_attributions': [],
#  'result': {'address_components': [{'long_name': 'New York',
#     'short_name': 'New York',
#     'types': ['locality', 'political']},
#    {'long_name': 'Manhattan',
#     'short_name': 'Manhattan',
#     'types': ['sublocality_level_1', 'sublocality', 'political']},
#    {'long_name': 'New York County',
#     'short_name': 'New York County',
#     'types': ['administrative_area_level_2', 'political']},
#    {'long_name': 'New York',
#     'short_name': 'NY',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': 'United States',
#     'short_name': 'US',
#     'types': ['country', 'political']},
#    {'long_name': '10004', 'short_name': '10004', 'types': ['postal_code']}],
#   'adr_address': '<span class="locality">New York</span>, <span class="region">NY</span> <span class="postal-code">10004</span>, <span class="country-name">USA</span>',
#   'business_status': 'OPERATIONAL',
#   'formatted_address': 'New York, NY 10004, USA',
#   'formatted_phone_number': '(212) 363-3200',
#   'geometry': {'location': {'lat': 40.6892494, 'lng': -74.04450039999999},
#    'viewport': {'northeast': {'lat': 40.71814749999999,
#      'lng': -73.99872490000001},
#     'southwest': {'lat': 40.6796167, 'lng': -74.05975889999998}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'international_phone_number': '+1 212-363-3200',
#   'name': 'Statue of Liberty National Monument',
#   'opening_hours': {'open_now': False,
#    'periods': [{'close': {'day': 0, 'time': '1600'},
#      'open': {'day': 0, 'time': '0830'}},
#     {'close': {'day': 1, 'time': '1600'}, 'open': {'day': 1, 'time': '0830'}},
#     {'close': {'day': 2, 'time': '1600'}, 'open': {'day': 2, 'time': '0830'}},
#     {'close': {'day': 3, 'time': '1600'}, 'open': {'day': 3, 'time': '0830'}},
#     {'close': {'day': 4, 'time': '1600'}, 'open': {'day': 4, 'time': '0830'}},
#     {'close': {'day': 5, 'time': '1600'}, 'open': {'day': 5, 'time': '0830'}},
#     {'close': {'day': 6, 'time': '1600'}, 'open': {'day': 6, 'time': '0830'}}],
#    'weekday_text': ['Monday: 8:30 AM – 4:00 PM',
#     'Tuesday: 8:30 AM – 4:00 PM',
#     'Wednesday: 8:30 AM – 4:00 PM',
#     'Thursday: 8:30 AM – 4:00 PM',
#     'Friday: 8:30 AM – 4:00 PM',
#     'Saturday: 8:30 AM – 4:00 PM',
#     'Sunday: 8:30 AM – 4:00 PM']},
#   'photos': [{'height': 4000,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105303505373661530610">indoorfish</a>'],
#     'photo_reference': 'ATtYBwKQG2NyMRuE8aMLqvnWcT355HgmwYM22Cp30OGcC_4EqpIYvE9GJ7INUtQiog19suWN5ge2eQ1U4A4i4kDBskg4fN3_xfk2689yaaKcwxeBxceXSLfXXrQ8ZczrfgMBhKWQe-A6W0NBFC89kqr6n0-O9g9dlPcRNTOeMTXKOLP8JDIN',
#     'width': 6000},
#    {'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101061177196295933157">Dave Pople</a>'],
#     'photo_reference': 'ATtYBwJ0RjRl7B6mWzDGM9yXfXSgaZDt44D-bRIHS3Bk2SNKOPFPTXsq5QYCVFj84EFJAxsDhFOLINsmuMZ8PGWj6_8KCPHdJiq3sHI4WEwAgPHp07uvRCxe_h5G6oeHBKizZ8Tm5Ulct4H-FUVqNtbvVj52yyr43iDHohKpyjTRV6D_srF0',
#     'width': 4032},
#    {'height': 1069,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115253754705102862912">Shabab Rakin</a>'],
#     'photo_reference': 'ATtYBwJz3jsG3WWt2QdjXYbcHoJT96T4w8zdDfqpHEm7HOYb9ZKWavU5JFsuXC6HkB-X_SMeOHDqdo6QiYjFuNCN6Qy8_rpEZQYg3oASqkN62kKCvqWmuPGLcPy50ybPLKd-fktqBz60gpHRjGOH5M4HYgh2Lkn09Qnu_zKUODewnbDX8Yzu',
#     'width': 720},
#    {'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107964365146276172972">Rodrigo Ortiz</a>'],
#     'photo_reference': 'ATtYBwK9bbjml2lfQHQ2wO3DGWXUTRJzVsdK3q02yy69qD5_k6VKF1cFrRQDPnmyVXlDM71_9EbKrfkg1KckU6oQqWOcJPXZQljLQpbT6nrY6t8iVMCjub0Ofjhx0YdqnT7ZMXG13Jgq69TWCe5c5gO1kBykQVCYFYQ4fHaNWiPIdLloUrjk',
#     'width': 4032},
#    {'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111514735588177976561">Paul Pavlinovich</a>'],
#     'photo_reference': 'ATtYBwKFcDWjJ00bLN6-g6O_apLeVB6HGkohx4zFvrucRB_JgxoOX4e6h6C7QSDPVm9h-mfEn6cNZ1KQaU6CXQxM6pNHPPVcUUld3YXdNxtNZEFv_gVjXMHabrDLM6GK4VuQB18PiZFe_LeyWfx7rcdBnMKFISBrI1Xf5LHvFjSH4Mn5GwN1',
#     'width': 4032},
#    {'height': 3968,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112990494192944168876">Alessandro Coladarci</a>'],
#     'photo_reference': 'ATtYBwIHeM77NVXP3PlOZFH2KfuBYCxJToyYl627Ktu75Ba4lb4twTu9mw1TNgY9tjomEup9qSJv7mMw9LIF1V5UHggDxoiJx1XnfBjjsoTb1vRB9za-ykv19OIoCAWgXDFqiH-cPW-SMrWIpqDUU3dqrX3V049qh0P0LKZDu2WyPXgo5U9S',
#     'width': 2976},
#    {'height': 2160,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110293063480331213664">Vance Ely</a>'],
#     'photo_reference': 'ATtYBwIAUbyKRA8Zso1vc7bzMgVx4FQBXB7Ws0xAs496RnfquZHU0D5rX9wsFxfUPzyfA4yIDgHq8KX2tU3w3uTUVKF0G8fWbbwWgf7dM-l0aJc7OWkoiYs5Nx0oDPpDQ7t83kHsCb2PAKkS2sjDWv-vJ45COKx9etZNkdrq1XY-6jQ0BJsN',
#     'width': 3840},
#    {'height': 3388,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109461782530437984994">Giuseppe Cherubini</a>'],
#     'photo_reference': 'ATtYBwL6Qk-t_Iv525PIhG9WbbXCt6F4Y4iIdorSHO6Qy07LZPAJwafhq0LzH9G92Tb5XxToAXJwJkNLPSQrEdH54iPZiRpVLkUX7JUNb_HKdiVJdeGpCPoQc4JaJVjwlxIDFS0ixOAI2A8y4SuQu83na67B5LHoZJb5j7oyqEcEsmZMZKhz',
#     'width': 2736},
#    {'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117724306101522221385">Jason Stanley</a>'],
#     'photo_reference': 'ATtYBwK_v6oFVUxRXVGwtNqSxDtKcQQ4W_-AObZu2AbIT35BnwPsjaOYXVOWFrvB8VdxoNKQdlWxHvNUiqJz9IwbOSGgpDGhKuqiVQP3ceAurZclss1w2AoqC7fj7q3kUqucZVnNZaDzVkxMoBKbCBJ6TuxmXesnecdzFGnf3DrN9BemnDM',
#     'width': 4032},
#    {'height': 4032,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101304671014197115630">chava Rose</a>'],
#     'photo_reference': 'ATtYBwI7nZ0OBKWNCJYS9OdM1kA8dCudsWf5Q885P8L1RBJJ2qslIDZk7g1Nwu1ldz6ucICTnxel1eKfarV-TMmyAfyDFBqk1XOU01ZBkZYEHpzmZFOfPliHtgsIPYr0wPAG2f2wtl_UUQs2j8T-t0QZm_7iA0-Dpmc8TcQ66OoCuPwuf6o',
#     'width': 3024}],
#   'place_id': 'ChIJPTacEpBQwokRKwIlDXelxkA',
#   'plus_code': {'compound_code': 'MXQ4+M5 New York, NY, USA',
#    'global_code': '87G7MXQ4+M5'},
#   'rating': 4.7,
#   'reference': 'ChIJPTacEpBQwokRKwIlDXelxkA',
#   'reviews': [{'author_name': 'SD SoCal',
#     'author_url': 'https://www.google.com/maps/contrib/113319036946822932614/reviews',
#     'language': 'en',
#     'profile_photo_url': 'https://lh3.googleusercontent.com/a-/AOh14GieU9zrde3Gv7VYodHTPjBiH4ub2QWCFYXt2k7t9g=s128-c0x00000000-cc-rp-mo',
#     'rating': 5,
#     'relative_time_description': '3 months ago',
#     'text': 'The place to go in NY! When I got to see Miss Liberty, I didn’t want to leave Liberty Island anymore, it’s a great place to be. From the island there’s a beautiful view over the skyline of Manhattan, which delivers great opportunities for taking breathtaking pictures of the city. Besides you are greeted by the world’s most majestic statue, which will leave impressed, by it‘s sheer height. Love it there and can’t wait to see Miss Liberty another time. Don‘t miss out!',
#     'time': 1598306574},
#    {'author_name': 'Prashant Kumar',
#     'author_url': 'https://www.google.com/maps/contrib/108725723377270945270/reviews',
#     'language': 'en',
#     'profile_photo_url': 'https://lh3.googleusercontent.com/a-/AOh14Gg-7iP3K_ElqFOcLlA2A34fT9QHTGwsrAPFtYggkg=s128-c0x00000000-cc-rp-mo',
#     'rating': 5,
#     'relative_time_description': '4 months ago',
#     'text': 'The Statue of Liberty was a joint effort between France and the United States, intended to commemorate the lasting friendship between the peoples of the two nations. The French sculptor Frederic-Auguste Bartholdi created the statue itself out of sheets of hammered copper, while Alexandre-Gustave Eiffel, the man behind the famed Eiffel Tower, designed the statue’s steel framework. The Statue of Liberty was then given to the United States and erected atop an American-designed pedestal on a small island in Upper New York Bay, now known as Liberty Island, and dedicated by President Grover Cleveland in 1886. Over the years, the statue stood tall as millions of immigrants arrived in America via nearby Ellis Island; in 1986, it underwent an extensive renovation in honor of the centennial of its dedication. Today, the Statue of Liberty remains an enduring symbol of freedom and democracy, as well as one of the world’s most recognizable landmarks.\nThis is wonderful place 🔥🔥',
#     'time': 1595844729},
#    {'author_name': 'Peter Nicholls',
#     'author_url': 'https://www.google.com/maps/contrib/111390698911789501910/reviews',
#     'language': 'en',
#     'profile_photo_url': 'https://lh3.googleusercontent.com/-KDIpU0crrcs/AAAAAAAAAAI/AAAAAAAAAAA/AMZuucmvo9z5hCKJws2AQDdtKJ__ccGKhg/s128-c0x00000000-cc-rp-mo-ba5/photo.jpg',
#     'rating': 5,
#     'relative_time_description': 'a week ago',
#     'text': 'Great to go see something as influential and well known. The ticket is good value and very inclusive but it can be difficult to understand the difference between all ticket types. Book early and get to go up to the higher levels.\n\nMake sure you stop off at the museum, also well worth it. Bring plenty of water if it is a hot day as the island is very exposed to the sun.',
#     'time': 1606628850},
#    {'author_name': 'Danillo Leite',
#     'author_url': 'https://www.google.com/maps/contrib/107484478796185857328/reviews',
#     'language': 'en',
#     'profile_photo_url': 'https://lh3.googleusercontent.com/a-/AOh14Gi4cWBU89puJKwZa658XpYiPXQkBBdPpkpY1i0IRw=s128-c0x00000000-cc-rp-mo',
#     'rating': 3,
#     'relative_time_description': '2 months ago',
#     'text': 'One of the best iconic structure and you will feel it while visiting this place. There is a great history why the color of the statue got changed. There are 2 options either take a ferry tour and see it from the ferry and waterfront, the other one is to go there and buy additional ticket. I seriously prefer the first option as these monuments always looks good from far.',
#     'time': 1601310898},
#    {'author_name': 'ashish goel',
#     'author_url': 'https://www.google.com/maps/contrib/106336604452681943078/reviews',
#     'language': 'en',
#     'profile_photo_url': 'https://lh3.googleusercontent.com/a-/AOh14GiiFR63f49NwcGl0lGZIaCsVYhS5sC-ocxkDixIX3g=s128-c0x00000000-cc-rp-mo-ba4',
#     'rating': 3,
#     'relative_time_description': 'in the last week',
#     'text': 'One of the best iconic structure and you will feel it while visiting this place. There is a great history why the color of the statue got changed. There are 2 options either take a ferry tour and see it from the ferry and waterfront, the other one is to go there and buy additional ticket. I seriously prefer the first option as these monuments always looks good from far.\n\nAnswer these questions\nWhat is the statue made of?\nIs the torch open?\nWho built it?\nDoes lighting effect this?\n\nThinking of other questions...',
#     'time': 1607218512}],
#   'types': ['tourist_attraction',
#    'park',
#    'point_of_interest',
#    'establishment'],
#   'url': 'https://maps.google.com/?cid=4667599994556318251',
#   'user_ratings_total': 72809,
#   'utc_offset': -300,
#   'vicinity': 'New York',
#   'website': 'https://www.nps.gov/stli/index.htm'},
#  'status': 'OK'}

# %% [markdown]
# ### Get Place Photos
# Each place details has reference to multiple photos which can be used for fetching actual image and with this we can train our baseline recommendation system.
#
# Using photo reference we can download the actual images or can specify the width and height based on our needs.

# %%
f = open('filename_1.jpg', 'wb')
for chunk in gmaps.places_photo(photo_reference='CmRaAAAA6x1lZ1fpmJt1nQL5MEkkKmLxsQBjGTzh9t_v3KydhgjT9PA8DxLxYxNy9OexrFIGFVuA2Zkks--S_5bIkDDEbaLL8sgF38IouNhOR77GS9nTxRCLUBrMwS1oCBFZQFbzEhA6chXDghK_cxio-98HMcnRGhRLih5KGNhBxTlh5pty47if2E1Dew', max_width=2988, max_height=5312):
    if chunk:
        f.write(chunk)
f.close()

# %%
f = open('filename_2.jpg', 'wb')
for chunk in gmaps.places_photo(photo_reference='CmRaAAAA6x1lZ1fpmJt1nQL5MEkkKmLxsQBjGTzh9t_v3KydhgjT9PA8DxLxYxNy9OexrFIGFVuA2Zkks--S_5bIkDDEbaLL8sgF38IouNhOR77GS9nTxRCLUBrMwS1oCBFZQFbzEhA6chXDghK_cxio-98HMcnRGhRLih5KGNhBxTlh5pty47if2E1Dew', max_width=400, max_height=400):
    if chunk:
        f.write(chunk)
f.close()
